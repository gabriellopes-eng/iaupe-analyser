# %%
import pandas as pd

# Mostrar a tabela inteira, sem truncar colunas, texto nem linhas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', None)
pd.set_option('display.max_rows', None)

dados_docentes = 'TRATADO - Experiência Profissional Docentes e Servidores da UPE (respostas).xlsx'

# Load the Excel file
df = pd.read_excel(dados_docentes)
df
